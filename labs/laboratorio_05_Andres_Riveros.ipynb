# %% [markdown]
# <img src="images/usm.jpg" width="480" height="240" align="left"/>

# %% [markdown]
# # MAT281 - Laboratorio N°05
#
# ## Objetivos de la clase
#
# * Reforzar los conceptos básicos de visualización.

# %% [markdown]
# ## Contenidos
#
# * [Problema 01](#p1)

# %% [markdown]
# ## Problema 01
#
# <img src="http://nelsoncos.com/wp-content/uploads/2017/02/sales-icon.png" width="360" height="360" align="center"/>
#
#
# EL conjunto de datos se denomina `company_sales_data.csv`, el cual contiene información tal como: número del mes, unidades, precio, etc.
#
# Lo primero es cargar el conjunto de datos y ver las primeras filas que lo componen:

# %%
import pandas as pd
import numpy as np
import os
import seaborn as sns
import matplotlib.pyplot as plt

sns.set(rc={'figure.figsize':(10,8)})

# %%
# cargar datos
df = pd.read_csv(os.path.join("data","company_sales_data.csv"))
df
# Out:
#     month_number  facecream  facewash  toothpaste  bathingsoap  shampoo  \
# 0              1       2500      1500        5200         9200     1200
# 1              2       2630      1200        5100         6100     2100
# 2              3       2140      1340        4550         9550     3550
# 3              4       3400      1130        5870         8870     1870
# 4              5       3600      1740        4560         7760     1560
# 5              6       2760      1555        4890         7490     1890
# 6              7       2980      1120        4780         8980     1780
# 7              8       3700      1400        5860         9960     2860
# 8              9       3540      1780        6100         8100     2100
# 9             10       1990      1890        8300        10300     2300
# 10            11       2340      2100        7300        13300     2400
# 11            12       2900      1760        7400        14400     1800
#
#     moisturizer  total_units  total_profit
# 0          1500        21100        211000
# 1          1200        18330        183300
# 2          1340        22470        224700
# 3          1130        22270        222700
# 4          1740        20960        209600
# 5          1555        20140        201400
# 6          1120        29550        295500
# 7          1400        36140        361400
# 8          1780        23400        234000
# 9          1890        26670        266700
# 10         2100        41280        412800
# 11         1760        30020        300200

# %% [markdown]
# El objetivo es tratar de obtener la mayor información posible de este conjunto de datos. Para cumplir este objetivo debe resolver las siguientes problemáticas:
#
# **Observación.-** Puedes ocupar las librerías de Matplolib o Seaborn.

# %% [markdown]
# 1. Lea el "total_profit" de todos los meses, muéstrelo usando un gráfico lineal y un gráfico de dispersión.

# %%
#Gráfico lineal
sns.lineplot(
    x='month_number',
    y='total_profit',
    data=df,
    ci = None,
)
# Out:
# <AxesSubplot:xlabel='month_number', ylabel='total_profit'>

# %%
#Gráfico de dispersión
sns.scatterplot(
    x='month_number',
    y='total_profit',
    data=df
)
# Out:
# <AxesSubplot:xlabel='month_number', ylabel='total_profit'>

# %% [markdown]
# 2. Lea todos los datos de ventas de productos y muéstrelos utilizando un gráfico multilínea.

# %%
pkmn_type_colors = ['#78C850',  # Grass
                    '#F08030',  # Fire
                    '#6890F0',  # Water
                    '#A8B820',  # Bug
                    '#A8A878',  # Normal
                    '#A040A0',  # Poison
                   ]
l=[]
for i in range(6):
    l.append((df.columns[1:-2][i],pkmn_type_colors[i]))


for procol in l:
    plt.plot(
        df['month_number'], # eje x
        df[procol[0]], # eje y
        label=procol[0], # etiquetado
        color=procol[1], # color
        linewidth=1 # tamano de la curva
    )
plt.legend() # agregar etiquetado
plt.title("ventas de productos") # agregar titulo
plt.xlabel('meses') # nombre eje x
plt.ylabel('ganancias') # nombre eje y
plt.grid() # agregar grillado
plt.show() # mostrar grafico

######   FACEWASH SE SUPERPONE A MOISTURIZER EN EL GRÁFICO DADO QUE SON LOS MISMOS DATOS ####

# %% [markdown]
# 3. Lea los datos de ventas de productos de "facecream" y "facewash" y muéstrelos usando el gráfico de barras.

# %%
sns.barplot(
    x='month_number',
    y='facecream',
    data=df 
)
# Out:
# <AxesSubplot:xlabel='month_number', ylabel='facecream'>

# %%
sns.barplot(
    x='month_number',
    y='facewash',
    data=df 
)
# Out:
# <AxesSubplot:xlabel='month_number', ylabel='facewash'>

# %% [markdown]
# 4. Lea todos los datos de ventas de productos y muéstrelos utilizando un gráfico box-plot.

# %%
stats_df = df.drop(['month_number', 'total_units', 'total_profit'], axis=1)

sns.boxplot(data=stats_df)
# Out:
# <AxesSubplot:>

# %% [markdown]
# 5. Calcule los datos de ventas totales del año pasado para cada producto y muéstrelos usando un gráfico circular

# %%
ventas=[]
for prod in df.columns[1:-2]:
    ventas.append(np.sum(df[prod]))

labels = df.columns[1:-2]
sizes = ventas

fig1, ax1 = plt.subplots()
ax1.pie(sizes, labels=labels, autopct='%1.1f%%')
ax1.axis('equal') 
plt.show()
